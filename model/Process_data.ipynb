# %%
import pandas as pd

# %%
df1 = pd.read_csv(r"C:\Users\kingd\Ennovar\data\products.csv")
df2 = pd.read_csv(r"C:\Users\kingd\Ennovar\data\transactions.csv")

merged = pd.merge(df1, df2, on="Product ID", how="inner")
merged=merged[merged['Currency']=='USD']
# df=merged[['Date','Category','Sub Category','Transaction Type','Quantity','Invoice Total','Size','Line Total']].copy()
merged
# Out:
#          Product ID  Category       Sub Category  \
# 0                 1  Feminine  Coats and Blazers
# 1                 1  Feminine  Coats and Blazers
# 2                 1  Feminine  Coats and Blazers
# 3                 1  Feminine  Coats and Blazers
# 4                 1  Feminine  Coats and Blazers
# ...             ...       ...                ...
# 6416809       17940  Children        Accessories
# 6416810       17940  Children        Accessories
# 6416811       17940  Children        Accessories
# 6416812       17940  Children        Accessories
# 6416813       17940  Children        Accessories
#
#                                     Description PT  \
# 0                Esportivo Veludo Verde Com Botões
# 1                Esportivo Veludo Verde Com Botões
# 2                Esportivo Veludo Verde Com Botões
# 3                Esportivo Veludo Verde Com Botões
# 4                Esportivo Veludo Verde Com Botões
# ...                                            ...
# ...

# %%
df["Date"]=pd.to_datetime(df["Date"])

# %%
x=df[(df["Date"].dt.year==2023) & (df["Category"]=="Feminine") & (df["Sub Category"]=="Coats and Blazers") & (df["Size"]=="M")].copy()
x
# Out:
#                        Date  Category       Sub Category Transaction Type  \
# 0       2023-01-01 13:28:00  Feminine  Coats and Blazers             Sale
# 4       2023-01-04 09:46:00  Feminine  Coats and Blazers             Sale
# 5       2023-01-09 18:10:00  Feminine  Coats and Blazers             Sale
# 10      2023-01-01 20:45:00  Feminine  Coats and Blazers             Sale
# 13      2023-01-07 12:20:00  Feminine  Coats and Blazers             Sale
# ...                     ...       ...                ...              ...
# 6284724 2023-01-01 00:00:00  Feminine  Coats and Blazers           Return
# 6305495 2023-01-01 00:00:00  Feminine  Coats and Blazers           Return
# 6322907 2023-01-03 00:00:00  Feminine  Coats and Blazers           Return
# 6393436 2023-01-01 00:00:00  Feminine  Coats and Blazers           Return
# 6405871 2023-01-04 00:00:00  Feminine  Coats and Blazers           Return
#
#          Quantity  Invoice Total Size  Line Total
# ...

# %%
check_sum=x["Line Total"].sum()
check_sum
# Out:
# np.float64(816958.95)
